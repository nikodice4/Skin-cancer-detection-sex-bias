# %%
import pandas as pd
from sklearn.datasets import make_regression
from sklearn.feature_selection import r_regression

# %%
data = pd.read_csv('../../data/metadata/augmented_master_data.csv')

# %%
data = data[["pigment_network_coverage", "blue_veil_pixels", "globules_count", "streaks_irregularity",
    "irregular_pigmentation_coverage", "regression_pixels", "compactness_x", "avg_red_channel", 
    "avg_green_channel", "avg_blue_channel", "multicolor_rate", "average_hue",
    "average_saturation", "average_value", "mean_asymmetry", "best_asymmetry", "worst_asymmetry",
    "red_var", "green_var", "blue_var", "hue_var", "sat_var", "val_var", "dom_hue", "dom_sat", 
    "dom_val", "compactness_y", "convexity", "F1", "F2", "F3", "F10", "F11", "F12", "is_cancerous"]]

# %%
data.head()
# Out:
#    pigment_network_coverage  blue_veil_pixels  globules_count  \
# 0                 31.808472             15934             147
# 1                  3.352356               787              31
# 2                  1.129150              1017              26
# 3                  2.539062              2456              61
# 4                  7.284546              7151              88
#
#    streaks_irregularity  irregular_pigmentation_coverage  regression_pixels  \
# 0              1.351892                        48.722839               3658
# 1              1.273240                         5.000305                197
# 2              1.273240                         1.687622                  0
# 3              0.000000                         3.817749                  4
# 4              1.273240                         9.098816                 94
#
#    compactness_x  avg_red_channel  avg_green_channel  avg_blue_channel  ...  \
# 0      11.803233         0.558304           0.515547          0.460685  ...
# 1       9.261028         0.692783           0.620616          0.550434  ...
# 2      13.344698         0.494076           0.363118          0.325845  ...
# 3      18.551896         0.870384           0.628618          0.651276  ...
# 4       9.768867         0.496641           0.322781          0.342710  ...
#
#     dom_val  compactness_y  convexity        F1        F2        F3       F10  \
# 0  0.579424       0.219393   0.962966  0.364677  0.335503  0.299820 -0.034850
# 1  0.704909       0.274984   0.952915  0.371866  0.332556  0.295579  0.057868
# 2  0.497338       0.181509   0.796362  0.414319  0.308571  0.277110  0.043913
# 3  0.861828       0.132457   0.142129  0.406513  0.291836  0.301651  0.144839
# 4  0.533349       0.261120   0.965536  0.436669  0.275235  0.288097 -0.015926
#
#         F11       F12  is_cancerous
# 0 -0.079849 -0.134889             0
# 1 -0.015329 -0.084182             0
# 2 -0.083993 -0.122046             0
# 3 -0.099453 -0.078544             0
# 4 -0.190253 -0.176363             1
#
# [5 rows x 35 columns]

# %%
X, y = make_regression(n_samples=50, n_features=34, n_informative=1, noise=1e-4, random_state=42)
r_regression(X, y)
# Out:
# array([-0.35811446, -0.02678189,  0.04041074,  0.21101906, -0.00140804,
#        -0.01246674,  0.26126747, -0.08730733, -0.24400334, -0.10613836,
#         0.04591153, -0.15730623, -0.1179591 , -0.04855402,  0.01740683,
#         0.12194374, -0.20613588,  0.14945084, -0.20294473,  0.19364488,
#        -0.28120543,  0.08935683,  0.11710423,  0.21930408, -0.00757123,
#        -0.00325605,  0.23355705,  0.15742176,  0.03280284,  0.24702952,
#        -0.27378269,  0.10238723,  0.09328351,  1.        ])

# %%
target_column = 'is_cancerous'  # Replace this with the actual name of the target column

# Calculate correlation with the target
correlation_with_target = data.corr()[target_column].drop(target_column)

# Display the correlations sorted by absolute value
sorted_correlation = correlation_with_target.abs().sort_values(ascending=False)
print(sorted_correlation)
# Out:
# F2                                 0.375630
# blue_veil_pixels                   0.268069
# sat_var                            0.249362
# average_hue                        0.240589
# pigment_network_coverage           0.207701
# irregular_pigmentation_coverage    0.194878
# F11                                0.188046
# F1                                 0.175276
# dom_hue                            0.173717
# multicolor_rate                    0.173225
# globules_count                     0.161645
# blue_var                           0.159874
# mean_asymmetry                     0.154802
# worst_asymmetry                    0.150873
# best_asymmetry                     0.143626
# green_var                          0.140067
# convexity                          0.139878
# average_saturation                 0.118863
# avg_green_channel                  0.101623
# dom_val                            0.100119
# compactness_x                      0.089043
# average_value                      0.080946
# avg_red_channel                    0.078545
# F12                                0.061923
# regression_pixels                  0.060621
# dom_sat                            0.049076
# F10                                0.044147
# compactness_y                      0.043822
# val_var                            0.020175
# hue_var                            0.019714
# red_var                            0.016977
# F3                                 0.008074
# streaks_irregularity               0.005802
# avg_blue_channel                   0.003986
# Name: is_cancerous, dtype: float64

# %%
import pandas as pd
import numpy as np

rs = np.random.RandomState(0)
df = data
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_49917_row0_col0, #T_49917_row1_col1, #T_49917_row2_col2, #T_49917_row3_col3, #T_49917_row4_col4, #T_49917_row5_col5, #T_49917_row6_col6, #T_49917_row7_col7, #T_49917_row7_col13, #T_49917_row8_col8, #T_49917_row9_col9, #T_49917_row10_col10, #T_49917_row11_col11, #T_49917_row12_col12, #T_49917_row13_col7, #T_49917_row13_col13, #T_49917_row14_col14, #T_49917_row15_col15, #T_49917_row16_col16, #T_49917_row17_col17, #T_49917_row18_col18, #T_49917_row19_col19, #T_49917_row20_col20, #T_49917_row21_col21, #T_49917_row22_col22, #T_49917_row23_col23, #T_49917_row24_col24, #T_49917_row25_col25, #T_49917_row26_col26, #T_49917_row27_col27, #T_49917_row28_col28, #T_49917_row29_col29, #T_49917_row30_col30, #T_49917_row31_col31, #T_49917_row32_col32, #T_49917_row33_col33, #T_49917_row34_col34 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_49917_row0_col1, #T_49917_row4_col1, #T_49917_row13_col8 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_49917_row0_col2, #T_49917_row2_col0, #T_49917_row29_col30 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_49917_row0_col3, #T_49917_row1_col31, #T_49917_row3_col10, #T_49917_row9_col4, #T_49917_row11_col0, #T_49917_row14_col21, #T_49917_row15_col21, #T_49917_row15_col23, #T_49917_row16_col2, #T_49917_row16_col21, #T_49917_row17_col3, #T_49917_row21_col4, #T_49917_row25_col17, #T_49917_row32_col1 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_49917_row0_col4, #T_49917_row4_col0 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_49917_row0_col5, #T_49917_row1_col2, #T_49917_row3_col16, #T_49917_row7_col12, #T_49917_row7_col24, #T_49917_row7_col33, #T_49917_row23_col27, #T_49917_row25_col14, #T_49917_row25_col15, #T_49917_row33_col11 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_49917_row0_col6, #T_49917_row4_col6, #T_49917_row4_col26, #T_49917_row7_col6, #T_49917_row13_col6, #T_49917_row17_col6, #T_49917_row18_col34, #T_49917_row19_col24, #T_49917_row20_col8, #T_49917_row20_col23, #T_49917_row27_col34 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_49917_row0_col7, #T_49917_row5_col21, #T_49917_row8_col12, #T_49917_row15_col2, #T_49917_row17_col0, #T_49917_row21_col2, #T_49917_row24_col22, #T_49917_row26_col7, #T_49917_row28_col22, #T_49917_row30_col22, #T_49917_row34_col18 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_49917_row0_col8, #T_49917_row5_col6, #T_49917_row9_col1, #T_49917_row18_col8, #T_49917_row24_col6, #T_49917_row28_col7 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_49917_row0_col9, #T_49917_row0_col29, #T_49917_row3_col29, #T_49917_row5_col4, #T_49917_row5_col32, #T_49917_row10_col2, #T_49917_row11_col16, #T_49917_row13_col30, #T_49917_row18_col29, #T_49917_row33_col7, #T_49917_row33_col23 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_49917_row0_col10, #T_49917_row1_col17, #T_49917_row2_col11, #T_49917_row2_col20, #T_49917_row12_col7, #T_49917_row16_col20, #T_49917_row17_col2, #T_49917_row21_col5, #T_49917_row22_col2, #T_49917_row30_col19 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_49917_row0_col11, #T_49917_row4_col11, #T_49917_row5_col19, #T_49917_row12_col21, #T_49917_row22_col5, #T_49917_row23_col12, #T_49917_row26_col5, #T_49917_row30_col6 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_49917_row0_col12, #T_49917_row0_col28, #T_49917_row2_col30, #T_49917_row3_col24, #T_49917_row17_col27, #T_49917_row17_col30, #T_49917_row18_col16, #T_49917_row20_col15, #T_49917_row26_col24 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_49917_row0_col13, #T_49917_row0_col18, #T_49917_row0_col31, #T_49917_row1_col18, #T_49917_row11_col22, #T_49917_row12_col26, #T_49917_row21_col26, #T_49917_row22_col0, #T_49917_row26_col13, #T_49917_row28_col26, #T_49917_row32_col23, #T_49917_row33_col24, #T_49917_row33_col26 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_49917_row0_col14, #T_49917_row2_col29, #T_49917_row4_col14, #T_49917_row4_col34, #T_49917_row7_col30, #T_49917_row17_col20, #T_49917_row18_col24, #T_49917_row19_col12, #T_49917_row23_col16, #T_49917_row26_col9, #T_49917_row34_col1 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_49917_row0_col15, #T_49917_row0_col24, #T_49917_row1_col15, #T_49917_row4_col15, #T_49917_row4_col29, #T_49917_row10_col24, #T_49917_row17_col29, #T_49917_row18_col9, #T_49917_row23_col15, #T_49917_row25_col32, #T_49917_row25_col33 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_49917_row0_col16, #T_49917_row1_col26, #T_49917_row2_col17, #T_49917_row6_col2, #T_49917_row10_col20, #T_49917_row15_col33, #T_49917_row16_col33 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_49917_row0_col17, #T_49917_row1_col24, #T_49917_row7_col5, #T_49917_row16_col32, #T_49917_row20_col6, #T_49917_row21_col6, #T_49917_row24_col7, #T_49917_row33_col1 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_49917_row0_col19, #T_49917_row3_col17, #T_49917_row3_col22, #T_49917_row4_col21, #T_49917_row4_col32, #T_49917_row5_col18, #T_49917_row6_col17, #T_49917_row10_col25, #T_49917_row14_col3, #T_49917_row14_col25, #T_49917_row15_col22, #T_49917_row15_col25, #T_49917_row23_col21, #T_49917_row26_col0, #T_49917_row29_col22, #T_49917_row34_col2, #T_49917_row34_col25 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_49917_row0_col20, #T_49917_row2_col21, #T_49917_row24_col13, #T_49917_row24_col34, #T_49917_row27_col8 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_49917_row0_col21, #T_49917_row1_col21, #T_49917_row5_col22, #T_49917_row15_col31, #T_49917_row17_col34, #T_49917_row19_col2, #T_49917_row22_col9, #T_49917_row22_col34, #T_49917_row27_col1, #T_49917_row31_col29, #T_49917_row32_col28, #T_49917_row34_col4 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_49917_row0_col22, #T_49917_row11_col29, #T_49917_row15_col32, #T_49917_row17_col5, #T_49917_row26_col20, #T_49917_row28_col13, #T_49917_row28_col21 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_49917_row0_col23, #T_49917_row4_col13, #T_49917_row11_col32, #T_49917_row15_col13, #T_49917_row18_col0, #T_49917_row23_col26, #T_49917_row24_col17 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_49917_row0_col25, #T_49917_row5_col25, #T_49917_row6_col1, #T_49917_row6_col23, #T_49917_row8_col34, #T_49917_row17_col23 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_49917_row0_col26, #T_49917_row7_col29, #T_49917_row8_col11, #T_49917_row12_col6, #T_49917_row23_col29, #T_49917_row27_col33, #T_49917_row32_col24 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_49917_row0_col27, #T_49917_row4_col5, #T_49917_row4_col27, #T_49917_row29_col20, #T_49917_row29_col33 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_49917_row0_col30, #T_49917_row2_col16, #T_49917_row8_col14, #T_49917_row8_col15, #T_49917_row17_col15, #T_49917_row19_col9, #T_49917_row22_col12, #T_49917_row22_col15 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_49917_row0_col32, #T_49917_row2_col31, #T_49917_row4_col7, #T_49917_row8_col19, #T_49917_row9_col26, #T_49917_row14_col13, #T_49917_row15_col7, #T_49917_row16_col3, #T_49917_row20_col21, #T_49917_row24_col21, #T_49917_row26_col32 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_49917_row0_col33, #T_49917_row1_col20, #T_49917_row1_col29, #T_49917_row6_col3, #T_49917_row9_col6, #T_49917_row13_col29, #T_49917_row16_col8 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_49917_row0_col34, #T_49917_row5_col0 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_49917_row1_col0, #T_49917_row1_col4 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_49917_row1_col3, #T_49917_row7_col1, #T_49917_row8_col4, #T_49917_row9_col28, #T_49917_row10_col3, #T_49917_row10_col31, #T_49917_row12_col10, #T_49917_row13_col1, #T_49917_row14_col10, #T_49917_row25_col1, #T_49917_row30_col0 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_49917_row1_col5 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_49917_row1_col6, #T_49917_row5_col23, #T_49917_row18_col6, #T_49917_row19_col6, #T_49917_row20_c

# %%
# Set a threshold for correlation (0.8 as per your requirement)
correlation_threshold = 0.8

# Compute the correlation matrix
corr_matrix = df.corr().abs()

upper_tri_mask = np.triu(np.ones(corr_matrix.shape), k=1).astype(bool)

# Filter the correlation matrix using the upper triangular mask
upper_tri_corr = corr_matrix.where(upper_tri_mask)

# List pairs of highly correlated features
highly_correlated_pairs = []
for feature in upper_tri_corr.columns:
    highly_correlated = upper_tri_corr[feature][upper_tri_corr[feature] >= correlation_threshold].index.tolist()
    for correlated_feature in highly_correlated:
        highly_correlated_pairs.append((feature, correlated_feature))

def get_correlation_count(correlation_pairs):
    feature_count = {}
    for pair in correlation_pairs:
        for feature in pair:
            feature_count[feature] = feature_count.get(feature, 0) + 1
    return feature_count

feature_count = get_correlation_count(highly_correlated_pairs)

feature_count = dict(sorted(feature_count.items(), key=lambda x:x[1], reverse=True))
print("feature count: ", feature_count)
highly_correlated_features = []
# Append features that appear more than once to the list
for feature, count in feature_count.items():
    if count > 1:
        highly_correlated_features.append(feature)

for feature, count in feature_count.items():
    if count > 1:
        print(feature, count)

# Print the list of features appearing twice or more
print(highly_correlated_features)

# Make a list of elements to remove from dataframe
to_drop = []

# Make a while loop that lasts until there are no more correlated features
while feature_count:
    while any(value >= 3 for value in feature_count.values()):
        # Find the feature with lowest correlation with target column
        features = [key for key, value in feature_count.items() if value >= 3]
        least_correlated_feature = None
        for feature in reversed(sorted_correlation.index):
            if feature in features:
                least_correlated_feature = feature
                break
        # Remove least correlated feature from the dictionary
        highly_correlated_pairs = [pair for pair in highly_correlated_pairs if least_correlated_feature not in pair]
        to_drop.append(least_correlated_feature)
        # Recalculate the correlation count
        feature_count = get_correlation_count(highly_correlated_pairs)
    
    while any(value == 2 for value in feature_count.values()):
        # Find the feature with lowest correlation with target column
        features = [key for key, value in feature_count.items() if value == 2]
        least_correlated_feature = None
        for feature in reversed(sorted_correlation.index):
            if feature in features:
                least_correlated_feature = feature
                break
        # Remove least correlated feature from the dictionary
        highly_correlated_pairs = [pair for pair in highly_correlated_pairs if least_correlated_feature not in pair]
        to_drop.append(least_correlated_feature)
        # Recalculate the correlation count
        feature_count = get_correlation_count(highly_correlated_pairs)

    while any(value == 1 for value in feature_count.values()):
        # Find the feature with lowest correlation with target column
        features = [key for key, value in feature_count.items() if value == 1]
        least_correlated_feature = None
        for feature in reversed(sorted_correlation.index):
            if feature in features:
                least_correlated_feature = feature
                break
        # Remove least correlated feature from the dictionary
        highly_correlated_pairs = [pair for pair in highly_correlated_pairs if least_correlated_feature not in pair]
        to_drop.append(least_correlated_feature)
        # Recalculate the correlation count
        feature_count = get_correlation_count(highly_correlated_pairs)

df_reduced = df.drop(columns=to_drop)

# Optionally, visualize the remaining correlation matrix
corr_reduced = df_reduced.corr()
corr_reduced.style.background_gradient(cmap='coolwarm')
# Out:
# feature count:  {'best_asymmetry': 3, 'mean_asymmetry': 3, 'worst_asymmetry': 3, 'dom_sat': 3, 'average_saturation': 3, 'convexity': 3, 'F1': 3, 'F3': 3, 'blue_veil_pixels': 2, 'pigment_network_coverage': 2, 'irregular_pigmentation_coverage': 2, 'average_value': 2, 'avg_red_channel': 2, 'dom_val': 2, 'avg_blue_channel': 1, 'avg_green_channel': 1, 'blue_var': 1, 'green_var': 1, 'val_var': 1, 'red_var': 1, 'F12': 1, 'F11': 1}
# best_asymmetry 3
# mean_asymmetry 3
# worst_asymmetry 3
# dom_sat 3
# average_saturation 3
# convexity 3
# F1 3
# F3 3
# blue_veil_pixels 2
# pigment_network_coverage 2
# irregular_pigmentation_coverage 2
# average_value 2
# avg_red_channel 2
# dom_val 2
# ['best_asymmetry', 'mean_asymmetry', 'worst_asymmetry', 'dom_sat', 'average_saturation', 'convexity', 'F1', 'F3', 'blue_veil_pixels', 'pigment_network_coverage', 'irregular_pigmentation_coverage', 'average_value', 'avg_red_channel', 'dom_val']
# _______________________________________
# features:  ['best_asymmetry', 'mean_asymmetry', 'worst_asymmetry', 'dom_sat', 'average_saturation', 'convexity', 'F1', 'F3']
# F3
# feature count:  {'blue_veil_pixels': 2, 'pigment_network_coverage': 2, 'irregular_pigmentation_coverage': 2, 'avg_blue_channel': 1, 'avg_green_channel': 1, 'average_value': 2, 'avg_red_channel': 2, 'best_asymmetry': 3, 'mean_asymmetry': 3, 'worst_asymmetry': 3, 'blue_var': 1, 'green_var': 1, 'val_var': 1, 'red_var': 1, 'dom_sat': 2, 'average_saturation': 2, 'dom_val': 2, 'convexity': 3, 'F1': 2, 'F12': 1, 'F11': 1}
# features:  ['best_asymmetry', 'mean_asymmetry', 'worst_asymmetry', 'convexity']
# convexity
# feature count:  {'blue_veil_pixels': 2, 'pigment_network_coverage': 2, 'irregular_pigmentation_coverage': 2, 'avg_blue_channel': 1, 'avg_green_channel': 1, 'average_value': 2, 'avg_red_channel': 2, 'best_asymmetry': 2, 'mean_asymmetry': 2, 'worst_asymmetry': 2, 'blue_var': 1, 'green_var': 1, 'val_var': 1, 'red_var': 1, 'dom_sat': 2, 'average_saturation': 2, 'dom_val': 2, 'F1': 2, 'F12': 1, 'F11': 1}
# features:  ['blue_veil_pixels', 'pigment_network_coverage', 'irregular_pigmentation_coverage', 'average_value', 'avg_red_channel', 'best_asymmetry', 'mean_asymmetry', 'worst_asymmetry', 'dom_sat', 'average_saturation', 'dom_val', 'F1']
# dom_sat
# feature count:  {'blue_veil_pixels': 2, 'pigment_network_coverage': 2, 'irregular_pigmentation_coverage': 2, 'avg_blue_channel': 1, 'avg_green_channel': 1, 'average_value': 2, 'avg_red_channel': 2, 'best_asymmetry': 2, 'mean_asymmetry': 2, 'worst_asymmetry': 2, 'blue_var': 1, 'green_var': 1, 'val_var': 1, 'red_var': 1, 'dom_val': 2, 'F1': 1, 'average_saturation': 1, 'F12': 1, 'F11': 1}
# features:  ['blue_veil_pixels', 'pigment_network_coverage', 'irregular_pigmentation_coverage', 'average_value', 'avg_red_channel', 'best_asymmetry', 'mean_asymmetry', 'worst_asymmetry', 'dom_val']
# avg_red_channel
# feature count:  {'blue_veil_pixels': 2, 'pigment_network_coverage': 2, 'irregular_pigmentation_coverage': 2, 'avg_blue_channel': 1, 'avg_green_channel': 1, 'best_asymmetry': 2, 'mean_asymmetry': 2, 'worst_asymmetry': 2, 'blue_var': 1, 'green_var': 1, 'val_var': 1, 'red_var': 1, 'dom_val': 1, 'average_value': 1, 'F1': 1, 'average_saturation': 1, 'F12': 1, 'F11': 1}
# features:  ['blue_veil_pixels', 'pigment_network_coverage', 'irregular_pigmentation_coverage', 'best_asymmetry', 'mean_asymmetry', 'worst_asymmetry']
# best_asymmetry
# feature count:  {'blue_veil_pixels': 2, 'pigment_network_coverage': 2, 'irregular_pigmentation_coverage': 2, 'avg_blue_channel': 1, 'avg_green_channel': 1, 'worst_asymmetry': 1, 'mean_asymmetry': 1, 'blue_var': 1, 'green_var': 1, 'val_var': 1, 'red_var': 1, 'dom_val': 1, 'average_value': 1, 'F1': 1, 'average_saturation': 1, 'F12': 1, 'F11': 1}
# features:  ['blue_veil_pixels', 'pigment_network_coverage', 'irregular_pigmentation_coverage']
# irregular_pigmentation_coverage
# feature count:  {'blue_veil_pixels': 1, 'pigment_network_coverage': 1, 'avg_blue_channel': 1, 'avg_green_channel': 1, 'worst_asymmetry': 1, 'mean_asymmetry': 1, 'blue_var': 1, 'green_var': 1, 'val_var': 1, 'red_var': 1, 'dom_val': 1, 'average_value': 1, 'F1': 1, 'average_saturation': 1, 'F12': 1, 'F11': 1}
# features:  ['blue_veil_pixels', 'pigment_network_coverage', 'avg_blue_channel', 'avg_green_channel', 'worst_asymmetry', 'mean_asymmetry', 'blue_var', 'green_var', 'val_var', 'red_var', 'dom_val', 'average_value', 'F1', 'average_saturation', 'F12', 'F11']
# avg_blue_channel
# feature count:  {'blue_veil_pixels': 1, 'pigment_network_coverage': 1, 'worst_asymmetry': 1, 'mean_asymmetry': 1, 'blue_var': 1, 'green_var': 1, 'val_var': 1, 'red_var': 1, 'dom_val': 1, 'average_value': 1, 'F1': 1, 'average_saturation': 1, 'F12': 1, 'F11': 1}
# features:  ['blue_veil_pixels', 'pigment_network_coverage', 'worst_asymmetry', 'mean_asymmetry', 'blue_var', 'green_var', 'val_var', 'red_var', 'dom_val', 'average_value', 'F1', 'average_saturation', 'F12', 'F11']
# red_var
# feature count:  {'blue_veil_pixels': 1, 'pigment_network_coverage': 1, 'worst_asymmetry': 1, 'mean_asymmetry': 1, 'blue_var': 1, 'green_var': 1, 'dom_val': 1, 'average_value': 1, 'F1': 1, 'average_saturation': 1, 'F12': 1, 'F11': 1}
# features:  ['blue_veil_pixels', 'pigment_network_coverage', 'worst_asymmetry', 'mean_asymmetry', 'blue_var', 'green_var', 'dom_val', 'average_value', 'F1', 'average_saturation', 'F12', 'F11']
# F12
# feature count:  {'blue_veil_pixels': 1, 'pigment_network_coverage': 1, 'worst_asymmetry': 1, 'mean_asymmetry': 1, 'blue_var': 1, 'green_var': 1, 'dom_val': 1, 'average_value': 1, 'F1': 1, 'average_saturation': 1}
# features:  ['blue_veil_pixels', 'pigment_network_coverage', 'worst_asymmetry', 'mean_asymmetry', 'blue_var', 'green_var', 'dom_val', 'average_value', 'F1', 'average_saturation']
# average_value
# feature count:  {'blue_veil_pixels': 1, 'pigment_network_coverage': 1, 'worst_asymmetry': 1, 'mean_asymmetry': 1, 'blue_var': 1, 'green_var': 1, 'F1': 1, 'average_saturation': 1}
# features:  ['blue_veil_pixels', 'pigment_network_coverage', 'worst_asymmetry', 'mean_asymmetry', 'blue_var', 'green_var', 'F1', 'average_saturation']
# average_saturation
# feature count:  {'blue_veil_pixels': 1, 'pigment_network_coverage': 1, 'worst_asymmetry': 1, 'mean_asymmetry': 1, 'blue_var': 1, 'green_var': 1}
# features:  ['blue_veil_pixels', 'pigment_network_coverage', 'worst_asymmetry', 'mean_asymmetry', 'blue_var', 'green_var']
# green_var
# feature count:  {'blue_veil_pixels': 1, 'pigment_network_coverage': 1, 'worst_asymmetry': 1, 'mean_asymmetry': 1}
# features:  ['blue_veil_pixels', 'pigment_network_coverage', 'worst_asymmetry', 'mean_asymmetry']
# worst_asymmetry
# feature count:  {'blue_veil_pixels': 1, 'pigment_network_coverage': 1}
# features:  ['blue_veil_pixels', 'pigment_network_coverage']
# pigment_network_coverage
# feature count:  {}
# ['F3', 'convexity', 'dom_sat', 'avg_red_channel', 'best_asymmetry', 'irregular_pigmentation_coverage', 'avg_blue_channel', 'red_var', 'F12', 'average_value', 'average_saturation', 'green_var', 'worst_asymmetry', 'pigment_network_coverage']
# length:  14
# <style type="text/css">
# #T_922af_row0_col0, #T_922af_row1_col1, #T_922af_row2_col2, #T_922af_row3_col3, #T_922af_row4_col4, #T_922af_row5_col5, #T_922af_row6_col6, #T_922af_row7_col7, #T_922af_row8_col8, #T_922af_row9_col9, #T_922af_row10_col10, #T_922af_row11_col11, #T_922af_row12_col12, #T_922af_row13_col13, #T_922af_row14_col14, #T_922af_row15_col15, #T_922af_row16_col16, #T_922af_row17_col17, #T_922af_row18_col18, #T_922af_row19_col19, #T_922af_row20_col20 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_922af_row0_col1, #T_922af_row16_col18 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_922af_row0_col2, #T_922af_row4_col15, #T_922af_row5_col12, #T_922af_row7_col1, #T_922af_row14_col2, #T_922af_row17_col18, #T_922af_row18_col9 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_922af_row0_col3 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_922af_row0_col4, #T_922af_row1_col15, #T_922af_row2_col13, #T_922af_row8_col2, #T_922af_row14_col10 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_922af_row0_col5 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_922af_row0_col6, #T_922af_row20_col18 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_922af_row0_col7 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_922af_row0_col8, #T_922af_row13_col4, #T_922af_row15_col6, #T_922af_row19_col20 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_922af_row0_col9, #T_922af_row1_col14, #T_922af_row2_col20, #T_922af_row11_col3, #T_922af_row20_col9 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_922af_row0_col10, #T_922af_row0_col17, #T_922af_row13_col5 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_922af_row0_col11, #T_922af_row3_col12, #T_922af_row4_col2, #T_922af_row12_col20, #T_922af_row13_col0, #T_922af_row18_col17 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_922af_row0_col12, #T_922af_row1_col9, #T_922af_row20_col3, #T_922af_row20_col10 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_922af_row0_col13, #T_922af_row2_col8, #T_922af_row15_col0 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_922af_row0_col14, #T_922af_row1_col2, #T_922af_row8_col13, #T_922af_row14_col11 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_922af_row0_col15, #T_922af_row6_col1, #T_922af_row6_col10, #T_922af_row9_col5 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_922af_row0_col16, #T_922af_row8_col19, #T_922af_row11_col7 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_922af_row0_col18, #T_922af_row1_col13, #T_922af_row2_col6, #T_922af_row3_col4, #T_922af_row7_col8, #T_922af_row8_col11 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_922af_row0_col19, #T_922af_row4_col14, #T_922af_row6_col8, #T_922af_row9_col14, #T_922af_row10_col15, #T_922af_row14_col6, #T_922af_row19_col7 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_922af_row0_col20, #T_922af_row9_col10 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_922af_row1_col0 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_922af_row1_col3, #T_922af_row1_col4, #T_922af_row9_col17, #T_922af_row12_col17 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_922af_row1_col5, #T_922af_row5_col10 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_922af_row1_col6, #T_922af_row8_col17, #T_922af_row12_col10 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_922af_row1_col7, #T_922af_row10_col20, #T_922af_row12_col1, #T_922af_row20_col15 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_922af_row1_col8, #T_922af_row4_col10 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_922af_row1_col10, #T_922af_row3_col1, #T_922af_row9_col13, #T_922af_row15_col7 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_922af_row1_col11, #T_922af_row2_col5, #T_922af_row6_col5, #T_922af_row12_col3 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_922af_row1_col12 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_922af_row1_col16, #T_922af_row7_col20 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_922af_row1_col17 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_922af_row1_col18, #T_922af_row10_col11, #T_922af_row14_col4, #T_922af_row15_col19 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_922af_row1_col19, #T_922af_row5_col4, #T_922af_row18_col3, #T_922af_row20_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_922af_row1_col20, #T_922af_row6_col17, #T_922af_row9_col20 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_922af_row2_col0, #T_922af_row8_col20, #T_922af_row16_col6 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_922af_row2_col1, #T_922af_row4_col0, #T_922af_row6_col19, #T_922af_row18_col7 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_922af_row2_col3, #T_922af_row7_col12, #T_922af_row7_col16, #T_922af_row11_col15, #T_922af_row16_col15, #T_922af_row19_col16 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_922af_row2_col4 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_922af_row2_col7, #T_922af_row3_col6, #T_922af_row4_col12, #T_922af_row9_col1, #T_922af_row9_col19, #T_922af_row12_col7, #T_922af_row13_col19 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_922af_row2_col9, #T_922af_row17_col7, #T_922af_row20_col19 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_922af_row2_col10, #T_922af_row3_col13, #T_922af_row3_col20, #T_922af_row6_col7, #T_922af_row10_col9 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_922af_row2_col11, #T_922af_row4_col7, #T_922af_row4_col20, #T_922af_row9_col8, #T_922af_row12_col15, #T_922af_row13_col12, #T_922af_row15_col13, #T_922af_row17_col15, #T_922af_row18_col15, #T_922af_row19_col4 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_922af_row2_col12, #T_922af_row5_col8, #T_922af_row6_col14, #T_922af_row8_col14, #T_922af_row13_col11, #T_922af_row17_col12, #T_922af_row20_col5, #T_922af_row20_col14 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_922af_row2_col14, #T_922af_row9_col18, #T_922af_row11_col1, #T_922af_row13_col6, #T_922af_row19_col13 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_922af_row2_col15 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_922af_row2_col16, #T_922af_row2_col17, #T_922af_row3_col7, #T_922af_row3_col19 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_922af_row2_col18, #T_922af_row4_col3, #T_922af_row5_col13, #T_922af_row10_col6, #T_922af_row12_col8 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_922af_row2_col19, #T_922af_row4_col18, #T_922af_row7_col9, #T_922af_row7_col15, #T_922af_row17_col8 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_922af_row3_col0 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_922af_row3_col2, #T_922af_row8_col15, #T_922af_row10_col14, #T_922af_row10_col18, #T_922af_row15_col1, #T_922af_row15_col2, #T_922af_row15_col4, #T_922af_row15_col8, #T_922af_row16_col0, #T_922af_row16_col3, #T_922af_row16_col5, #T_922af_row16_col7, #T_922af_row16_col9, #T_922af_row16_col10, #T_922af_row16_col13, #T_922af_row16_col17, #T_922af_row16_col19, #T_922af_row17_col16, #T_922af_row17_col20, #T_922af_row18_col12, #T_922af_row19_col1, #T_922af_row19_col6, #T_922af_row19_col11 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_922af_row3_col5, #T_922af_row17_col10 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_922af_row3_col8, #T_922af_row11_col8 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_922af_row3_col9, #T_922af_row7_col17, #T_922af_row15_col5, #T_922af_row15_col10, #T_922af_row16_col11 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_922af_row3_col10 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_922af_row3_col11, #T_922af_row5_col9, #T_922af_row12_col0, #T_922af_row15_col18, #T_922af_row16_col8, #T_922af_row16_col12, #T_922af_row17_col4 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_922af_row3_col14, #T_922af_row5_col20, #T_922af_row10_col0, #T_922af_row18_col4 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_922af_row3_col15, #T_922af_row7_col11, #T_922af_row13_col16, #T_922af_row14_col3, #T_922af_row18_co

# %%
# # Set the correlation threshold for identifying pairs of highly correlated features
# # Set the correlation threshold for identifying pairs of highly correlated features
# correlation_threshold = 0.8

# # Calculate the correlation matrix (absolute values) between all features
# corr_matrix = df.corr().abs()

# # Set the target variable name
# target_column = 'is_cancerous'  # Replace with your target column name

# # Calculate correlations with the target variable and sort them by absolute values
# correlation_with_target = df.corr()[target_column].drop(target_column)
# sorted_correlation = correlation_with_target.abs().sort_values(ascending=False)

# # Initialize an empty set to hold features to keep
# selected_features = set()

# # Iterate over features sorted by their correlation with the target
# for feature in sorted_correlation.index:
#     if feature not in selected_features:
#         # Add this feature to the selected set
#         selected_features.add(feature)

#         # Identify features highly correlated with this one
#         highly_corr_features = corr_matrix[feature][corr_matrix[feature] > correlation_threshold].index

#         # Add all highly correlated features to the set, except the one already added
#         selected_features.update(highly_corr_features)

# # Finally, create a list of features to keep
# features_to_keep = list(set(df.columns) - selected_features)

# # Create the reduced dataframe
# df_reduced = df[features_to_keep + [target_column]]

# # Optionally, visualize the remaining correlation matrix
# corr_reduced = df_reduced.corr()
# corr_reduced.style.background_gradient(cmap='coolwarm')

# # Print the remaining columns
# #print(f"Remaining columns after filtering: {df_reduced.columns.tolist()}")

# #print(f"Remaining columns after filtering: {df_reduced.columns.tolist()}")
# Out:
# list of pairs:  [('feature1', 'feature2'), ('feature2', 'feature3'), ('feature4', 'feature5'), ('feature1', 'feature6')]
# Filtered list: [('feature2', 'feature3'), ('feature4', 'feature5')]

# %%
target_column = 'is_cancerous'  # Replace this with the actual name of the target column

# Calculate correlation with the target
correlation_with_target = corr_reduced.corr()[target_column].drop(target_column)

# Display the correlations sorted by absolute value
sorted_correlation = correlation_with_target.abs().sort_values(ascending=False)
print(sorted_correlation)
# Out:
# F2                      0.669753
# F11                     0.520174
# sat_var                 0.456324
# blue_veil_pixels        0.425394
# avg_green_channel       0.422833
# mean_asymmetry          0.413267
# F1                      0.394285
# average_hue             0.354082
# compactness_x           0.322502
# dom_hue                 0.299340
# multicolor_rate         0.291959
# blue_var                0.215404
# globules_count          0.214780
# hue_var                 0.168523
# streaks_irregularity    0.146996
# compactness_y           0.128469
# val_var                 0.114950
# F10                     0.104578
# dom_val                 0.059822
# regression_pixels       0.055705
# Name: is_cancerous, dtype: float64
